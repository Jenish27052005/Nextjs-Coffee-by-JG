# %%
# !pip install pygit2==1.15.1
# %cd /content
# !git clone https://github.com/lllyasviel/Fooocus.git
# %cd /content/Fooocus
# !python entry_with_update.py --share --always-high-vram
# Out:
# Collecting pygit2==1.15.1
#   Downloading pygit2-1.15.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.3 kB)
# Requirement already satisfied: cffi>=1.16.0 in /usr/local/lib/python3.11/dist-packages (from pygit2==1.15.1) (1.17.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.16.0->pygit2==1.15.1) (2.22)
# Downloading pygit2-1.15.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.1/5.1 MB 67.3 MB/s eta 0:00:00
# Installing collected packages: pygit2
#   Attempting uninstall: pygit2
#     Found existing installation: pygit2 1.18.0
#     Uninstalling pygit2-1.18.0:
#       Successfully uninstalled pygit2-1.18.0
# Successfully installed pygit2-1.15.1
# /content
# Cloning into 'Fooocus'...
# remote: Enumerating objects: 6725, done.
# remote: Total 6725 (delta 0), reused 0 (delta 0), pack-reused 6725 (from 1)
# Receiving objects: 100% (6725/6725), 33.33 MiB | 9.35 MiB/s, done.
# Resolving deltas: 100% (3855/3855), done.
# /content/Fooocus
# Already up-to-date
# Update succeeded.
# [System ARGV] ['entry_with_update.py', '--share', '--always-high-vram']
# Python 3.11.12 (main, Apr  9 2025, 08:55:54) [GCC 11.4.0]
# Fooocus version: 2.5.5
# Error checking version for torchsde: No package metadata was found for torchsde
# Installing requirements
# [Cleanup] Attempting to delete content of temp dir /tmp/fooocus
# [Cleanup] Cleanup successful
# Downloading: "https://huggingface.co/lllyasviel/misc/resolve/main/xlvaeapp.pth" to /content/Fooocus/models/vae_approx/xlvaeapp.pth
#
# 100% 209k/209k [00:00<00:00, 56.2MB/s]
# Downloading: "https://huggingface.co/lllyasviel/misc/resolve/main/vaeapp_sd15.pt" to /content/Fooocus/models/vae_approx/vaeapp_sd15.pth
#
# 100% 209k/209k [00:00<00:00, 29.0MB/s]
# Downloading: "https://huggingface.co/mashb1t/misc/resolve/main/xl-to-v1_interposer-v4.0.safetensors" to /content/Fooocus/models/vae_approx/xl-to-v1_interposer-v4.0.safetensors
#
# 100% 5.40M/5.40M [00:00<00:00, 230MB/s]
# Downloading: "https://huggingface.co/lllyasviel/misc/resolve/main/fooocus_expansion.bin" to /content/Fooocus/models/prompt_expansion/fooocus_expansion/pytorch_model.bin
#
# 100% 335M/335M [00:01<00:00, 341MB/s]
# Downloading: "https://huggingface.co/lllyasviel/fav_models/resolve/main/fav/juggernautXL_v8Rundiffusion.safetensors" to /content/Fooocus/models/checkpoints/juggernautXL_v8Rundiffusion.safetensors
#
# 100% 6.62G/6.62G [00:43<00:00, 163MB/s]
# Downloading: "https://huggingface.co/stabilityai/stable-diffusion-xl-base-1.0/resolve/main/sd_xl_offset_example-lora_1.0.safetensors" to /content/Fooocus/models/loras/sd_xl_offset_example-lora_1.0.safetensors
#
# 100% 47.3M/47.3M [00:00<00:00, 496MB/s]
# Total VRAM 15095 MB, total RAM 12978 MB
# Set vram state to: HIGH_VRAM
# Always offload VRAM
# Device: cuda:0 Tesla T4 : native
# VAE dtype: torch.float32
# Using pytorch cross attention
# Refiner unloaded.
# Running on local URL:  http://127.0.0.1:7865
# IMPORTANT: You are using gradio version 3.41.2, however version 4.44.1 is available, please upgrade.
# --------
# model_type EPS
# UNet ADM Dimension 2816
# Running on public URL: https://c8312081d3ccf33559.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# Using pytorch attention in VAE
# Working with z of shape (1, 4, 32, 32) = 4096 dimensions.
# Using pytorch attention in VAE
# extra {'cond_stage_model.clip_l.text_projection', 'cond_stage_model.clip_l.logit_scale'}
# left over keys: dict_keys(['cond_stage_model.clip_l.transformer.text_model.embeddings.position_ids'])
# loaded straight to GPU
# Requested to load SDXL
# Loading 1 new model
# Base model loaded: /content/Fooocus/models/checkpoints/juggernautXL_v8Rundiffusion.safetensors
# VAE loaded: None
# Request to load LoRAs [('sd_xl_offset_example-lora_1.0.safetensors', 0.1)] for model [/content/Fooocus/models/checkpoints/juggernautXL_v8Rundiffusion.safetensors].
# Loaded LoRA [/content/Fooocus/models/loras/sd_xl_offset_example-lora_1.0.safetensors] for UNet [/content/Fooocus/models/checkpoints/juggernautXL_v8Rundiffusion.safetensors] with 788 keys at weight 0.1.
# Fooocus V2 Expansion: Vocab with 642 words.
# Fooocus Expansion engine loaded for cuda:0, use_fp16 = True.
# Requested to load SDXLClipModel
# Requested to load GPT2LMHeadModel
# Loading 2 new models
# [Fooocus Model Management] Moving model(s) has taken 0.59 seconds
# 2025-05-28 04:48:30.992371: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1748407711.268474    3576 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1748407711.340328    3576 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-05-28 04:48:31.915618: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Started worker with PID 2533
# App started successful. Use the app with http://127.0.0.1:7865/ or 127.0.0.1:7865 or https://c8312081d3ccf33559.gradio.live
# [Parameters] Adaptive CFG = 7
# [Parameters] CLIP Skip = 2
# [Parameters] Sharpness = 2
# [Parameters] ControlNet Softness = 0.25
# [Parameters] ADM Scale = 1.5 : 0.8 : 0.3
# [Parameters] Seed = 0
# [Parameters] CFG = 4
# [Fooocus] Loading control models ...
# [Parameters] Sampler = dpmpp_2m_sde_gpu - karras
# [Parameters] Steps = 30 - 15
# [Fooocus] Initializing ...
# [Fooocus] Loading models ...
# Refiner unloaded.
# [Fooocus] Processing prompts ...
# [Fooocus] Preparing Fooocus text #1 ...
# [Prompt Expansion] A young Indian woman in her early 20s with expressive eyes, long black hair styled in soft waves, wearing a modern yet traditional outfit — a fusion of a kurti with jeans, standing in natural light with a warm, confident smile. She is standing against a cityscape background (like Mumbai or Bangalore), looking stylish and friendly. High-resolution, realistic style, Instagram influencer aesthetic, vibrant colors, DSLR quality, beautiful gorgeous, very inspirational, elegant, intricate, detailed, rich deep color, epic composition, cinematic, dramatic ambient, sharp focus, complex, amazing creative, positive, cute, attractive, sublime, iconic, pure, fine, best, contemporary, vivid, illuminated, clear, pretty, futuristic, highly decorated
# [Fooocus] Preparing Fooocus text #2 ...
# [Prompt Expansion] A young Indian woman in her early 20s with expressive eyes, long black hair styled in soft waves, wearing a modern yet traditional outfit — a fusion of a kurti with jeans, standing in natural light with a warm, confident smile. She is standing against a cityscape background (like Mumbai or Bangalore), looking stylish and friendly. High-resolution, realistic style, Instagram influencer aesthetic, vibrant colors, DSLR quality, excellent composition, cinematic, detailed, deep rich color, beautiful, dramatic, epic breathtaking, complex, inspiring, highly structured, amazing, creative, cool, intense, lovely, marvelous, elegant, luxury, elaborate, colorful, wonderful, awesome, fantastic, fabulous, flowing, very intricate, ambient, thought, pretty
# [Fooocus] Encoding positive #1 ...
# [Fooocus Model Management] Moving model(s) has taken 0.18 seconds
# [Fooocus] Encoding positive #2 ...
# [Fooocus] Encoding negative #1 ...
# [Fooocus] Encoding negative #2 ...
# [Parameters] Denoising Strength = 1.0
# [Parameters] Initial Latent shape: Image Space (1024, 1024)
# Preparation time: 3.83 seconds
# Using karras scheduler.
# [Fooocus] Preparing task 1/2 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 1.64 seconds
# 100% 30/30 [00:27<00:00,  1.09it/s]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.30 seconds
# [Fooocus] Saving image 1/2 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2025-05-28/log.html
# Generating and saving time: 32.29 seconds
# [Fooocus] Preparing task 2/2 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.72 seconds
# 100% 30/30 [00:28<00:00,  1.05it/s]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.27 seconds
# [Fooocus] Saving image 2/2 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2025-05-28/log.html
# Generating and saving time: 32.22 seconds
# [Enhance] Skipping, preconditions aren't met
# Processing time (total): 64.51 seconds
# Requested to load SDXLClipModel
# Requested to load GPT2LMHeadModel
# Loading 2 new models
# Total time: 68.40 seconds
# [Fooocus Model Management] Moving model(s) has taken 0.83 seconds
# [Parameters] Adaptive CFG = 7
# [Parameters] CLIP Skip = 2
# [Parameters] Sharpness = 2
# [Parameters] ControlNet Softness = 0.25
# [Parameters] ADM Scale = 1.5 : 0.8 : 0.3
# [Parameters] Seed = 1
# [Parameters] CFG = 4
# [Fooocus] Loading control models ...
# [Parameters] Sampler = dpmpp_2m_sde_gpu - karras
# [Parameters] Steps = 60 - 30
# [Fooocus] Initializing ...
# [Fooocus] Loading models ...
# Refiner unloaded.
# [Fooocus] Processing prompts ...
# [Fooocus] Preparing Fooocus text #1 ...
# [Prompt Expansion] A young Indian woman in her early 20s with expressive eyes, long black hair styled in soft waves, wearing a modern yet traditional outfit — a fusion of a kurti with jeans, standing in natural light with a warm, confident smile. She is standing against a cityscape background (like Mumbai or Bangalore), looking stylish and friendly. High-resolution, realistic style, Instagram influencer aesthetic, vibrant colors, DSLR quality, excellent composition, cinematic, detailed, deep rich color, beautiful, dramatic, epic breathtaking, complex, inspiring, highly structured, amazing, creative, cool, intense, lovely, marvelous, elegant, luxury, elaborate, colorful, wonderful, awesome, fantastic, fabulous, flowing, very intricate, ambient, thought, pretty
# [Fooocus] Preparing Fooocus text #2 ...
# [Prompt Expansion] A young Indian woman in her early 20s with expressive eyes, long black hair styled in soft waves, wearing a modern yet traditional outfit — a fusion of a kurti with jeans, standing in natural light with a warm, confident smile. She is standing against a cityscape background (like Mumbai or Bangalore), looking stylish and friendly. High-resolution, realistic style, Instagram influencer aesthetic, vibrant colors, DSLR quality, sharp focus, intricate detail, very coherent, cinematic, rich, atmosphere, gorgeous, full color, beautiful, elegant, perfect, deep complimentary complex, highly detailed, stunning, ambient dramatic dynamic, glowing, symmetry, pristine, pretty, focused, creative, positive, innocent, pure, illuminating, scientific, meaningful
# [Fooocus] Encoding positive #1 ...
# [Fooocus Model Management] Moving model(s) has taken 0.13 seconds
# [Fooocus] Encoding positive #2 ...
# [Fooocus] Encoding negative #1 ...
# [Fooocus] Encoding negative #2 ...
# [Parameters] Denoising Strength = 1.0
# [Parameters] Initial Latent shape: Image Space (1024, 1024)
# Preparation time: 2.21 seconds
# Using karras scheduler.
# [Fooocus] Preparing task 1/2 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 1.23 seconds
# 100% 60/60 [00:56<00:00,  1.06it/s]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.30 seconds
# [Fooocus] Saving image 1/2 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2025-05-28/log.html
# Generating and saving time: 60.69 seconds
# [Fooocus] Preparing task 2/2 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.62 seconds
# 100% 60/60 [00:54<00:00,  1.10it/s]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.34 seconds
# [Fooocus] Saving image 2/2 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2025-05-28/log.html
# Generating and saving time: 58.46 seconds
# [Enhance] Skipping, preconditions aren't met
# Processing time (total): 119.15 seconds
# Requested to load SDXLClipModel
# Requested to load GPT2LMHeadModel
# Loading 2 new models
# Total time: 121.41 seconds
# [Fooocus Model Management] Moving model(s) has taken 0.91 seconds
# Loaded preset: /content/Fooocus/presets/realistic.json
# Downloading: "https://huggingface.co/lllyasviel/fav_models/resolve/main/fav/realisticStockPhoto_v20.safetensors" to /content/Fooocus/models/checkpoints/realisticStockPhoto_v20.safetensors
#
# 100% 6.46G/6.46G [02:00<00:00, 57.5MB/s]
# Downloading: "https://huggingface.co/mashb1t/fav_models/resolve/main/fav/SDXL_FILM_PHOTOGRAPHY_STYLE_V1.safetensors" to /content/Fooocus/models/loras/SDXL_FILM_PHOTOGRAPHY_STYLE_V1.safetensors
#
# 100% 870M/870M [00:13<00:00, 67.1MB/s]
# Loaded preset: /content/Fooocus/presets/playground_v2.5.json
# Downloading: "https://huggingface.co/mashb1t/fav_models/resolve/main/fav/playground-v2.5-1024px-aesthetic.fp16.safetensors" to /content/Fooocus/models/checkpoints/playground-v2.5-1024px-aesthetic.fp16.safetensors
#
# 100% 6.46G/6.46G [01:49<00:00, 63.5MB/s]
# Loaded preset: /content/Fooocus/presets/lightning.json
# Loaded preset: /content/Fooocus/presets/realistic.json
# [Parameters] Adaptive CFG = 7
# [Parameters] CLIP Skip = 2
# [Parameters] Sharpness = 2
# [Parameters] ControlNet Softness = 0.25
# [Parameters] ADM Scale = 1.5 : 0.8 : 0.3
# [Parameters] Seed = 1
# [Parameters] CFG = 3
# [Fooocus] Loading control models ...
# [Parameters] Sampler = dpmpp_2m_sde_gpu - karras
# [Parameters] Steps = 60 - 30
# [Fooocus] Initializing ...
# [Fooocus] Loading models ...
# Refiner unloaded.
# model_type EPS
# UNet ADM Dimension 2816
# Using pytorch attention in VAE
# Working with z of shape (1, 4, 32, 32) = 4096 dimensions.
# Using pytorch attention in VAE
# extra {'cond_stage_model.clip_l.text_projection', 'cond_stage_model.clip_l.logit_scale'}
# left over keys: dict_keys(['cond_stage_model.clip_l.transformer.text_model.embeddings.position_ids'])
# loaded straight to GPU
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 1.88 seconds
# Base model loaded: /content/Fooocus/models/checkpoints/realisticStockPhoto_v20.safetensors
# VAE loaded: None
# Request to load LoRAs [('SDXL_FILM_PHOTOGRAPHY_STYLE_V1.safetensors', 0.25)] for model [/content/Fooocus/models/checkpoints/realisticStockPhoto_v20.safetensors].
# Loaded LoRA [/content/Fooocus/models/loras/SDXL_FILM_PHOTOGRAPHY_STYLE_V1.safetensors] for UNet [/content/Fooocus/models/checkpoints/realisticStockPhoto_v20.safetensors] with 722 keys at weight 0.25.
# Loaded LoRA [/content/Fooocus/models/loras/SDXL_FILM_PHOTOGRAPHY_STYLE_V1.safetensors] for CLIP [/content/Fooocus/models/checkpoints/realisticStockPhoto_v20.safetensors] with 264 keys at weight 0.25.
# Requested to load SDXLClipModel
# Requested to load GPT2LMHeadModel
# Loading 2 new models
# [Fooocus Model Management] Moving model(s) has taken 1.33 seconds
# [Fooocus] Processing prompts ...
# [Fooocus] Preparing Fooocus text #1 ...
# [Prompt Expansion] A young Indian woman in her early 20s with expressive eyes, long black hair styled in soft waves, wearing a modern yet traditional outfit — a fusion of a kurti with jeans, standing in natural light with a warm, confident smile. She is standing against a cityscape background (like Mumbai or Bangalore), looking stylish and friendly. High-resolution, realistic style, Instagram influencer aesthetic, vibrant colors, DSLR quality, excellent composition, cinematic, detailed, deep rich color, beautiful, dramatic, epic breathtaking, complex, inspiring, highly structured, amazing, creative, cool, intense, lovely, marvelous, elegant, luxury, elaborate, colorful, wonderful, awesome, fantastic, fabulous, flowing, very intricate, ambient, thought, pretty
# [Fooocus] Preparing Fooocus text #2 ...
# [Prompt Expansion] A young Indian woman in her early 20s with expressive eyes, long black hair styled in soft waves, wearing a modern yet traditional outfit — a fusion of a kurti with jeans, standing in natural light with a warm, confident smile. She is standing against a cityscape background (like Mumbai or Bangalore), looking stylish and friendly. High-resolution, realistic style, Instagram influencer aesthetic, vibrant colors, DSLR quality, sharp focus, intricate detail, very coherent, cinematic, rich, atmosphere, gorgeous, full color, beautiful, elegant, perfect, deep complimentary complex, highly detailed, stunning, ambient dramatic dynamic, glowing, symmetry, pristine, pretty, focused, creative, positive, innocent, pure, illuminating, scientific, meaningful
# [Fooocus] Encoding positive #1 ...
# [Fooocus Model Management] Moving model(s) has taken 0.12 seconds
# [Fooocus] Encoding positive #2 ...
# [Fooocus] Encoding negative #1 ...
# [Fooocus] Encoding negative #2 ...
# [Parameters] Denoising Strength = 1.0
# [Parameters] Initial Latent shape: Image Space (1024, 1024)
# Preparation time: 44.82 seconds
# Using karras scheduler.
# [Fooocus] Preparing task 1/2 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 1.85 seconds
# 100% 60/60 [01:01<00:00,  1.02s/it]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.27 seconds
# [Fooocus] Saving image 1/2 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2025-05-28/log.html
# Generating and saving time: 66.07 seconds
# [Fooocus] Preparing task 2/2 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.81 seconds
# 100% 60/60 [01:00<00:00,  1.00s/it]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.30 seconds
# [Fooocus] Saving image 2/2 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2025-05-28/log.html
# Generating and saving time: 64.01 seconds
# [Enhance] Skipping, preconditions aren't met
# Processing time (total): 130.09 seconds
# Requested to load SDXLClipModel
# Requested to load GPT2LMHeadModel
# Loading 2 new models
# Total time: 174.96 seconds
# [Fooocus Model Management] Moving model(s) has taken 1.02 seconds
# [Parameters] Adaptive CFG = 7
# [Parameters] CLIP Skip = 2
# [Parameters] Sharpness = 2
# [Parameters] ControlNet Softness = 0.25
# [Parameters] ADM Scale = 1.5 : 0.8 : 0.3
# [Parameters] Seed = 1
# [Parameters] CFG = 3
# [Fooocus] Loading control models ...
# [Parameters] Sampler = dpmpp_2m_sde_gpu - karras
# [Parameters] Steps = 60 - 30
# [Fooocus] Initializing ...
# [Fooocus] Loading models ...
# Refiner unloaded.
# [Fooocus] Processing prompts ...
# [Fooocus] Preparing Fooocus text #1 ...
# [Prompt Expansion] A young Indian woman in her early 20s with expressive eyes, long black hair styled in soft waves, wearing a modern yet traditional outfit — a fusion of a kurti with jeans, standing in natural light with a warm, confident smile. She is standing against a cityscape background (like Mumbai or Bangalore), looking stylish and friendly. High-resolution, realistic style, Instagram influencer aesthetic, vibrant colors, iphone quality, gorgeous, cinematic, elegant, intricate detailed, very inspirational, beautiful, cute, creative, inspiring, positive, joyful, unique, pure, attractive, pretty, romantic, passionate, amazing, scenic, fancy, best, dramatic, perfect, brilliant, awesome, flowing, bright, complex, highly marked professional
# [Fooocus] Preparing Fooocus text #2 ...
# [Prompt Expansion] A young Indian woman in her early 20s with expressive eyes, long black hair styled in soft waves, wearing a modern yet traditional outfit — a fusion of a kurti with jeans, standing in natural light with a warm, confident smile. She is standing against a cityscape background (like Mumbai or Bangalore), looking stylish and friendly. High-resolution, realistic style, Instagram influencer aesthetic, vibrant colors, iphone quality, sharp focus, intricate, very inspirational, cinematic, elegant,, rich deep color, dramatic ambient epic, highly detailed, excellent composition, dynamic, beautiful, symmetry, clear, crisp, artistic, cute, lovely, advanced, pretty, elite, gorgeous, marvelous, inspiring, thought, iconic, fancy, awesome
# [Fooocus] Encoding positive #1 ...
# [Fooocus Model Management] Moving model(s) has taken 0.13 seconds
# [Fooocus] Encoding positive #2 ...
# [Fooocus] Encoding negative #1 ...
# [Fooocus] Encoding negative #2 ...
# [Parameters] Denoising Strength = 1.0
# [Parameters] Initial Latent shape: Image Space (1024, 1024)
# Preparation time: 2.30 seconds
# Using karras scheduler.
# [Fooocus] Preparing task 1/2 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.92 seconds
# 100% 60/60 [01:01<00:00,  1.02s/it]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.26 seconds
# [Fooocus] Saving image 1/2 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2025-05-28/log.html
# Generating and saving time: 65.16 seconds
# [Fooocus] Preparing task 2/2 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.74 seconds
# 100% 60/60 [00:59<00:00,  1.00it/s]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.25 seconds
# [Fooocus] Saving image 2/2 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2025-05-28/log.html
# Generating and saving time: 63.39 seconds
# [Enhance] Skipping, preconditions aren't met
# Processing time (total): 128.54 seconds
# Requested to load SDXLClipModel
# Requested to load GPT2LMHeadModel
# Loading 2 new models
# Total time: 130.89 seconds
# [Fooocus Model Management] Moving model(s) has taken 1.00 seconds
# [Parameters] Adaptive CFG = 7
# [Parameters] CLIP Skip = 2
# [Parameters] Sharpness = 2
# [Parameters] ControlNet Softness = 0.25
# [Parameters] ADM Scale = 1.5 : 0.8 : 0.3
# [Parameters] Seed = 1
# [Parameters] CFG = 3
# [Fooocus] Loading control models ...
# [Parameters] Sampler = dpmpp_2m_sde_gpu - karras
# [Parameters] Steps = 60 - 30
# [Fooocus] Initializing ...
# [Fooocus] Loading models ...
# Refiner unloaded.
# [Fooocus] Processing prompts ...
# [Fooocus] Preparing Fooocus text #1 ...
# [Prompt Expansion] A young Indian woman in her early 20s with expressive eyes, long black hair styled in soft waves, wearing a modern yet hot outfit — a fusion of a kurti with jeans, standing in natural light with a warm, confident smile. She is standing against a cityscape background (like Mumbai or Bangalore), looking stylish and friendly. High-resolution, realistic style, Instagram influencer aesthetic, vibrant colors, iphone quality, gorgeous, cinematic, elegant, intricate, very coherent, detailed, sharp focus, rich deep color, amazing detail, pretty, inspiring, inspired, lovely, cute, creative, positive, cheerful, unique, loving, rational, thriving, beautiful, agile, attractive, fashionable, cool, passionate, successful, smart
# [Fooocus] Preparing Fooocus text #2 ...
# [Prompt Expansion] A young Indian woman in her early 20s with expressive eyes, long black hair styled in soft waves, wearing a modern yet hot outfit — a fusion of a kurti with jeans, standing in natural light with a warm, confident smile. She is standing against a cityscape background (like Mumbai or Bangalore), looking stylish and friendly. High-resolution, realistic style, Instagram influencer aesthetic, vibrant colors, iphone quality, sharp focus, intricate, very inspirational, cinematic, elegant,, rich deep color, dramatic ambient epic, highly detailed, excellent composition, dynamic, beautiful, symmetry, clear, crisp, artistic, cute, lovely, advanced, pretty, elite, gorgeous, marvelous, inspiring, thought, iconic, fancy, awesome
# [Fooocus] Encoding positive #1 ...
# [Fooocus Model Management] Moving model(s) has taken 0.13 seconds
# [Fooocus] Encoding positive #2 ...
# [Fooocus] Encoding negative #1 ...
# [Fooocus] Encoding negative #2 ...
# [Parameters] Denoising Strength = 1.0
# [Parameters] Initial Latent shape: Image Space (1024, 1024)
# Preparation time: 2.40 seconds
# Using karras scheduler.
# [Fooocus] Preparing task 1/2 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.93 seconds
# 100% 60/60 [01:01<00:00,  1.02s/it]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.26 seconds
# [Fooocus] Saving image 1/2 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2025-05-28/log.html
# Generating and saving time: 65.24 seconds
# [Fooocus] Preparing task 2/2 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.74 seconds
# 100% 60/60 [01:00<00:00,  1.00s/it]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.26 seconds
# [Fooocus] Saving image 2/2 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2025-05-28/log.html
# Generating and saving time: 63.79 seconds
# [Enhance] Skipping, preconditions aren't met
# Processing time (total): 129.03 seconds
# Requested to load SDXLClipModel
# Requested to load GPT2LMHeadModel
# Loading 2 new models
# Total time: 131.48 seconds
# [Fooocus Model Management] Moving model(s) has taken 1.01 seconds
# [Parameters] Adaptive CFG = 7
# [Parameters] CLIP Skip = 2
# [Parameters] Sharpness = 2
# [Parameters] ControlNet Softness = 0.25
# [Parameters] ADM Scale = 1.5 : 0.8 : 0.3
# [Parameters] Seed = 1
# [Parameters] CFG = 3
# [Fooocus] Downloading upscale models ...
# Downloading: "https://huggingface.co/lllyasviel/misc/resolve/main/fooocus_upscaler_s409985e5.bin" to /content/Fooocus/models/upscale_models/fooocus_upscaler_s409985e5.bin
#
# 100% 32.1M/32.1M [00:00<00:00, 391MB/s]
# [Fooocus] Loading control models ...
# [Parameters] Sampler = dpmpp_2m_sde_gpu - karras
# [Parameters] Steps = 0 - 0
# [Fooocus] Initializing ...
# [Fooocus] Image processing ...
# [Fooocus] Upscaling image from (1024, 1024) ...
# Upscaling image with shape (1024, 1024, 3) ...
# Image upscaled.
# [Fooocus] Saving image to system ...
# Image generated with private log at: /content/Fooocus/outputs/2025-05-28/log.html
# Total time: 20.07 seconds
# [Parameters] Adaptive CFG = 7
# [Parameters] CLIP Skip = 2
# [Parameters] Sharpness = 2
# [Parameters] ControlNet Softness = 0.25
# [Parameters] ADM Scale = 1.5 : 0.8 : 0.3
# [Parameters] Seed = 1
# [Parameters] CFG = 3
# [Fooocus] Loading control models ...
# [Parameters] Sampler = dpmpp_2m_sde_gpu - karras
# [Parameters] Steps = 60 - 30
# [Fooocus] Initializing ...
# [Fooocus] Loading models ...
# Refiner unloaded.
# [Fooocus] Processing prompts ...
# [Fooocus] Preparing Fooocus text #1 ...
# [Prompt Expansion] A young Indian woman in her early 20s with expressive eyes, long black hair styled in soft waves, wearing a modern yet hot outfit — a fusion of a kurti with jeans, standing in natural light with a warm, enjoy. She is standing against a cityscape background (like ahmedabad), looking stylish and friendly. High-resolution, realistic style, Instagram influencer aesthetic, vibrant colors, iphone quality, gorgeous, elegant, very coherent, detailed, sharp focus, beautiful, attractive, intricate, innocent, complex, creative, positive, artistic, romantic, pretty, color, ambient, iconic, fine detail, full open, lovely, inspired, amazing, pure, symmetry, perfect, cute, colorful, engaging, joyful
# [Fooocus] Preparing Fooocus text #2 ...
# [Prompt Expansion] A young Indian woman in her early 20s with expressive eyes, long black hair styled in soft waves, wearing a modern yet hot outfit — a fusion of a kurti with jeans, standing in natural light with a warm, enjoy. She is standing against a cityscape background (like ahmedabad), looking stylish and friendly. High-resolution, realistic style, Instagram influencer aesthetic, vibrant colors, iphone quality, sharp focus, intricate, very inspirational, cinematic, elegant, confident, color, highly detailed, innocent, pure, rational, cute, creative, positive, loving, generous, beautiful, inspired, glowing, perfect, focused, lovely, dramatic, illuminated, incredible, lucid, epic gorgeous, colorful, amazing, flowing
# [Fooocus] Encoding positive #1 ...
# [Fooocus Model Management] Moving model(s) has taken 0.16 seconds
# [Fooocus] Encoding positive #2 ...
# [Fooocus] Encoding negative #1 ...
# [Fooocus] Encoding negative #2 ...
# [Fooocus] Image processing ...
# [Fooocus] VAE encoding ...
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.46 seconds
# Final resolution is (2048, 2048).
# [Parameters] Denoising Strength = 0.5
# [Parameters] Initial Latent shape: torch.Size([1, 4, 256, 256])
# Preparation time: 12.57 seconds
# Using karras scheduler.
# [Fooocus] Preparing task 1/2 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 1.2431749105453491
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.85 seconds
# 100% 60/60 [05:19<00:00,  5.32s/it]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.39 seconds
# Warning: Ran out of memory when regular VAE decoding, retrying with tiled VAE decoding.
# [Fooocus] Saving image 1/2 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2025-05-28/log.html
# Generating and saving time: 381.30 seconds
# [Fooocus] Preparing task 2/2 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 1.2431749105453491
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.92 seconds
#  17% 10/60 [00:58<04:50,  5.82s/it]
# User stopped
# [Enhance] Skipping, preconditions aren't met
# Processing time (total): 440.40 seconds
# Requested to load SDXLClipModel
# Requested to load GPT2LMHeadModel
# Loading 2 new models
# Total time: 453.06 seconds
# [Fooocus Model Management] Moving model(s) has taken 1.08 seconds
# [Parameters] Adaptive CFG = 7
# [Parameters] CLIP Skip = 2
# [Parameters] Sharpness = 2
# [Parameters] ControlNet Softness = 0.25
# [Parameters] ADM Scale = 1.5 : 0.8 : 0.3
# [Parameters] Seed = 1
# [Parameters] CFG = 3
# [Fooocus] Loading control models ...
# [Parameters] Sampler = dpmpp_2m_sde_gpu - karras
# [Parameters] Steps = 60 - 30
# [Fooocus] Initializing ...
# [Fooocus] Loading models ...
# Refiner unloaded.
# [Fooocus] Processing prompts ...
# [Fooocus] Preparing Fooocus text #1 ...
# [Prompt Expansion] smilling, jumping on road, ahmedabad, riverfront background, face, epic, cinematic, dynamic, detailed, intricate, elegant, highly contrasted, futuristic, sharp focus, fair composition, dramatic light, professional, romantic, new, color, surreal, iconic, fine detail, clear, pretty, perfect, artistic, positive, nice, joyful, unique, cute
# [Fooocus] Preparing Fooocus text #2 ...
# [Prompt Expansion] smilling, jumping on road, ahmedabad, riverfront background, face, sharp focus, highly detailed, cinematic, lucid, intricate, surreal, beautiful, elegant, luxury, epic composition, dramatic light, illuminated, amazing, symmetry, great, perfect, peaceful, artistic, color, ambient dynamic, strong, crisp, focused, professional, winning, best, gorgeous
# [Fooocus] Encoding positive #1 ...
# [Fooocus Model Management] Moving model(s) has taken 0.16 seconds
# [Fooocus] Encoding positive #2 ...
# [Fooocus] Encoding negative #1 ...
# [Fooocus] Encoding negative #2 ...
# [Fooocus] Image processing ...
# [Fooocus] VAE encoding ...
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.50 seconds
# Final resolution is (2048, 2048).
# [Parameters] Denoising Strength = 0.85
# [Parameters] Initial Latent shape: torch.Size([1, 4, 256, 256])
# Preparation time: 12.40 seconds
# Using karras scheduler.
# [Fooocus] Preparing task 1/2 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 7.829630374908447
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.88 seconds
#  43% 26/60 [02:19<03:02,  5.36s/it]
# User stopped
# [Enhance] Skipping, preconditions aren't met
# Processing time (total): 140.27 seconds
# Requested to load SDXLClipModel
# Requested to load GPT2LMHeadModel
# Loading 2 new models
# Total time: 152.69 seconds
# [Fooocus Model Management] Moving model(s) has taken 0.98 seconds
# [Parameters] Adaptive CFG = 7
# [Parameters] CLIP Skip = 2
# [Parameters] Sharpness = 2
# [Parameters] ControlNet Softness = 0.25
# [Parameters] ADM Scale = 1.5 : 0.8 : 0.3
# [Parameters] Seed = 1
# [Parameters] CFG = 3
# [Fooocus] Loading control models ...
# [Parameters] Sampler = dpmpp_2m_sde_gpu - karras
# [Parameters] Steps = 60 - 30
# [Fooocus] Initializing ...
# [Fooocus] Loading models ...
# Refiner unloaded.
# [Fooocus] Processing prompts ...
# [Fooocus] Preparing Fooocus text #1 ...
# [Prompt Expansion] smilling, jumping on road, ahmedabad, riverfront background, dramatic light, cinematic, highly detailed, sharp focus, perfect composition, elegant, very inspirational, innocent, magic, aesthetic, ambient, deep color, epic, romantic, surreal, pretty, confident, artistic, striking, rich colors, inspired, new, shiny, colorful, great, fine detail
# [Fooocus] Preparing Fooocus text #2 ...
# [Prompt Expansion] smilling, jumping on road, ahmedabad, riverfront background, sharp focus, highly detailed, cinematic, still, dynamic composition, elegant, intricate, full color, very inspirational, fine, artistic, illuminated, pretty, smart, elite, dramatic, stylish, professional, thoughtful, vibrant, inspired, fancy,, epic, modern, futuristic, gorgeous, colorful
# [Fooocus] Encoding positive #1 ...
# [Fooocus Model Management] Moving model(s) has taken 0.13 seconds
# [Fooocus] Encoding positive #2 ...
# [Fooocus] Encoding negative #1 ...
# [Fooocus] Encoding negative #2 ...
# [Fooocus] Image processing ...
# [Fooocus] VAE encoding ...
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.46 seconds
# Final resolution is (2048, 2048).
# [Parameters] Denoising Strength = 0.5
# [Parameters] Initial Latent shape: torch.Size([1, 4, 256, 256])
# Preparation time: 11.37 seconds
# Using karras scheduler.
# [Fooocus] Preparing task 1/2 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 1.2431749105453491
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.81 seconds
# 100% 60/60 [05:09<00:00,  5.16s/it]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.29 seconds
# Warning: Ran out of memory when regular VAE decoding, retrying with tiled VAE decoding.
# [Fooocus] Saving image 1/2 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2025-05-28/log.html
# Generating and saving time: 371.05 seconds
# [Fooocus] Preparing task 2/2 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 1.2431749105453491
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.84 seconds
# 100% 60/60 [05:08<00:00,  5.15s/it]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.29 seconds
# Warning: Ran out of memory when regular VAE decoding, retrying with tiled VAE decoding.
# [Fooocus] Saving image 2/2 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2025-05-28/log.html
# Generating and saving time: 370.13 seconds
# [Enhance] Skipping, preconditions aren't met
# Processing time (total): 741.19 seconds
# Requested to load SDXLClipModel
# Requested to load GPT2LMHeadModel
# Loading 2 new models
# Total time: 752.64 seconds
# [Fooocus Model Management] Moving model(s) has taken 1.10 seconds
# Keyboard interruption in main thread... closing server.
# Killing tunnel 127.0.0.1:7865 <> https://c8312081d3ccf33559.gradio.live
# ^C
